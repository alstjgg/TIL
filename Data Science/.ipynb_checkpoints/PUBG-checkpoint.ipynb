# %% [markdown]
# ### [PUBG Finish Placement Prediction](https://www.kaggle.com/c/pubg-finish-placement-prediction/overview)
#
# ***
# # Acquire data
# - Use [Kaggle API](https://github.com/Kaggle/kaggle-api) to download competitions data from kaggle
#     1. Log in
#     2. Create API Token
#     3. Change Token directory to '.../.kaggle'
#     4. Accept [competition rules](https://www.kaggle.com/c/pubg-finish-placement-prediction/rules)
#     5. `kaggle competitions download -c pubg-finish-placement-prediction`

# %%
import pandas as pd
root = '/Users/13579/Desktop/Git/TIL/Data Science/data/pubg'
train_df = pd.read_csv(root + '/train.csv')
test_df = pd.read_csv(root + '/test.csv')

# %% [markdown]
# # Analyze data

# %% [markdown]
# #### Training Data Overview
# 4446966 samples 29 features
#
# <div class="alert alert-warning">
# <p> - Categorical: Id, groupId, matchId, matchType <br>
#     - Numerical: assists, boosts, damageDealt, DBNOs, headshotKills, heals, killPlace, killPoinst, kills, killStreaks, longestKill, matchDuration, maxPlace, numGroups, rankPoints, revives, rideDstance, roadKills, swimDistance, teamKills, vehicleDestroys, walkDistance, weaponsAcquired, winPoints, winPlacePerc <p></div>

# %%
train_df.describe()
# Out:
#             assists        boosts   damageDealt         DBNOs  headshotKills  \
# count  4.446966e+06  4.446966e+06  4.446966e+06  4.446966e+06   4.446966e+06
# mean   2.338149e-01  1.106908e+00  1.307171e+02  6.578755e-01   2.268196e-01
# std    5.885731e-01  1.715794e+00  1.707806e+02  1.145743e+00   6.021553e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 50%    0.000000e+00  0.000000e+00  8.424000e+01  0.000000e+00   0.000000e+00
# 75%    0.000000e+00  2.000000e+00  1.860000e+02  1.000000e+00   0.000000e+00
# max    2.200000e+01  3.300000e+01  6.616000e+03  5.300000e+01   6.400000e+01
#
#               heals     killPlace    killPoints         kills   killStreaks  \
# count  4.446966e+06  4.446966e+06  4.446966e+06  4.446966e+06  4.446966e+06
# mean   1.370147e+00  4.759935e+01  5.050060e+02  9.247833e-01  5.439551e-01
# ...

# %%
train_df.describe(include=['O'])
# Out:
#                     Id         groupId         matchId  matchType
# count          4446966         4446966         4446966    4446966
# unique         4446966         2026745           47965         16
# top     1dc717bc4c6944  14d6b54cdec6bc  ce4c906562179b  squad-fpp
# freq                 1              74             100    1756186

# %%
train_df[['damageDealt', 'winPlacePerc']].groupby(['damageDealt'], as_index=False)\
.mean().sort_values(by='winPlacePerc', ascending=False)
# Out:
#        damageDealt  winPlacePerc
# 29915    6616.0000           1.0
# 1129        0.4730           1.0
# 29612    2301.0000           1.0
# 29613    2303.0000           1.0
# 29614    2305.0000           1.0
# 6527        5.6390           1.0
# 28403     994.0000           1.0
# 28350     988.7000           1.0
# 6731        5.8560           1.0
# 29626    2326.0000           1.0
# 29627    2329.0000           1.0
# 29628    2330.0000           1.0
# 29629    2333.0000           1.0
# 6846        5.9820           1.0
# 1006        0.4186           1.0
# 6862        5.9980           1.0
# 29646    2371.0000           1.0
# 29647    2374.0000           1.0
# 29653    2386.0000           1.0
# 29654    2387.0000           1.0
# 7131        6.2870           1.0
# 29656    2391.0000           1.0
# 29657    2393.0000           1.0
# 29658    2395.0000           1.0
# 924         0.3835           1.0
# 29661    2401.0000           1.0
# 29662    2402.0000           1.0
# ...
